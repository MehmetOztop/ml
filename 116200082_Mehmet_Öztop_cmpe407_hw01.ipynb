# %%
import pandas as pd #importing pandas library for reading the data
import seaborn as sns #importing seaborn library to visualize the data
#reading and assigning the dataset to a variable
adm_data = pd.read_csv("C:/Users/Mehmet/Desktop/Dersler 2020 Bahar/Admission_Predict.csv")

# %%
adm_data[:3]
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72

# %%
sns.swarmplot(adm_data["GRE Score"], adm_data.iloc[:,8]) #plotting the chance of admit with regard to GRE score
#with some exceptions, clearly the chance of admit goes up proportionally to GRE scores.
#It seems to be that the universities in this dataset significantly value the GRE score of masters applicants

# %%
sns.violinplot(adm_data["TOEFL Score"], adm_data.iloc[:,8]) #plotting the chance of admit with regard to TOEFL score
#While there is still a correlation, there is a lot more variance compared to GRE scores here
#So, TOEFL scores have less significance for universities

# %%
sns.swarmplot(adm_data["University Rating"], adm_data.iloc[:,8]) #plotting the chance of admit with regard to university ratings
#there is a very straight forward relation here with little variance
#if a student has graduated from a better university, their chance of admit goes up for masters

# %%
sns.violinplot(adm_data["SOP"], adm_data.iloc[:,8]) #plotting the chance of admit with regard to statement of purpose
#Out of the first 4, this one has the weakest correlation, especially at the lower margins
#Compared to the previous criteria, the quality of a students statement of purpose move the dial the least

# %%
sns.barplot(adm_data.iloc[:,5], adm_data.iloc[:,8]) #plotting the chance of admit with regard to LOR
#there is a good correlation here with variance being mostly on the lower margins

# %%
sns.swarmplot(adm_data.iloc[:,6], adm_data.iloc[:,8]) #plotting the chance of admit with regard to CGPA
#CGPA trumps all
#While variance still exists, a students overall grade changes their chance of admit the most, especially at the higher margins
#with their chance going up with a higher GPA and going down with a lower GPA

# %%
sns.swarmplot(adm_data.iloc[:,7], adm_data.iloc[:,8]) #plotting the chance of admit with regard to research experience
#with little variance, having research experience gives a bump to students chance of admit

# %%
measures = ['GRE Score', "TOEFL Score", 'University Rating', 'SOP', 'LOR ', 'CGPA', 'Research'] 
#plotting the correlations of the variables with each other 
sns.pairplot(adm_data[measures],kind="reg")

# %%
sns.heatmap(adm_data[features].corr()) #plotting the heatmap of variable correlations
#while research experience has little to no correlation with other measures,
#standardized test scores and grades have a very strong correlation.
#Students' performance on one test tend to be similar to their other test scores and their CPGA

# %%
#Overall, doing better on all measures increases the chance of admit.
#With graduating from a high tier university with a high CGPA increasing a students chance of masters approval the most
